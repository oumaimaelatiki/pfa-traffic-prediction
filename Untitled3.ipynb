# %%
# !pip install pandas numpy

# %%
import pandas as pd
import numpy as np

# %%
# Adapte le chemin selon où est ton fichier
# Si le fichier est dans le même dossier que le notebook :
df = pd.read_csv('Housing (1).csv')

# Si tu as mis le fichier ailleurs, mets le chemin complet :
# df = pd.read_csv(r'C:\Users\...\Housing (1).csv')  # Windows
# df = pd.read_csv('/Users/.../Housing (1).csv')     # Mac

# %%
df = pd.read_csv('Housing (1).csv')
